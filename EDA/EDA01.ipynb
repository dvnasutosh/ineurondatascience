# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/googleplaystore.csv')

# %% [markdown]
# # ***EDA 1***
# We will be working with google playstore dataset
# ### **What is EDA?**
# - Exploratory Data Analysis
# - Summerize and organise clean and filter data from context of a data scientist.
#
# ### **Basic/Core work Pipeline of a Machine Learning Project**
# 1. Data Injestion - Data gathering, scraping.
# 2. Exploratory Data Analysis
# 3. Pre-Processing (*Feature Engineering*)
# 4. Model building (*ML Session*)
# 5. Validate or Evaluate the Model (*ML Session*)
#
# ### Data Injestion -(Overview)
# 1. Directly from files of preffered formats(csv,json,tsv,xls)
# 2. Cloud
# 3. NoSQL/SQL
# 4. Scrapping

# %% [markdown]
# # ***EDA + PP(FE)***
#
# ## EDA Steps
# 1. Profile of the data
# 2. Stats based analysis
# 3. Graph based analysis
# <br>
#
# ## Detailed steps
# 1. We have collcted the data(It will require analysis(*EDA*))
#     Raw ---*convert to profile*----> Profile
#     **Some things to add in profile**
#     - Rows
#     - Cols
#     - missing
#     - Outlier
#     - Size of data
#     - duplicate value
#     - Dtype
#     - Type of data
#     - RAM Usage
#     - Space
#
#     After listing out these details you do **data cleaning** to handle messy and incorrect data.
#
# 2. Stats based analysis
#    - Variance
#    - std
#    - Corr
#    - Cov
#    - Chi square
#    - T,z,f test
#    - skewness
#    - Mean
#    - median
#    - mode
#    - range
#    - percentile
#
# 3. Graph based analysis (You can make statistical conclusion)
#    - box plot
#    - scatter plot
#    - KDE
#    - count plot
#    - histogram
#    - heatmap

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
dfsample=df.sample(50)
dfsample
# Out:
#                                                      App            Category  \
# 5831   AY Recorder - Screen Recorder, Live, Video Editor               TOOLS
# 10334                                              FE IP               TOOLS
# 3564                         aCalendar+ Calendar & Tasks        PRODUCTIVITY
# 7910                             CU SoCal Mobile Banking             FINANCE
# 2873                                        Photo Editor         PHOTOGRAPHY
# 10644                                  South Florida MLS           LIFESTYLE
# 248                        Asana: organize team projects            BUSINESS
# 1633                                                Zara           LIFESTYLE
# 1302   Home workouts - fat burning, abs, legs, arms,c...  HEALTH_AND_FITNESS
# 33                                    Easy Origami Ideas      ART_AND_DESIGN
# 4113                                      F-Secure SENSE               TOOLS
# ...

# %% [markdown]
# # Data Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe().T #Transpose
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
dfdesc= df.describe(include='all') #To include all
dfdesc
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
data=df
data[data.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
data.Reviews.shape
# Out:
# (10841,)

# %%
data.Reviews.shape
# Out:
# (10841,)

# %%
data.Reviews.dtype
# Out:
# dtype('O')

# %% [markdown]
# # Data cleaning

# %%
data[~data.Reviews.str.isnumeric()]
# Shows non numeric data '~' used to get negetion pf the data

 # We could either replace it or remove the whole row
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
"""~x= -1*(x+1)"""
[~3,~4,~345]
# Out:
# [-4, -5, -346]

# %%
# Dropping the data as it is only a single data
data_copy=data.copy(deep=True)
print(data_copy[~data_copy.Reviews.str.isnumeric()])
data_copy=data_copy.drop(index= data_copy[~data_copy.Reviews.str.isnumeric()].index[0])
print('_'*23)
print(data_copy[~data_copy.Reviews.str.isnumeric()])
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN
# _______________________
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# convert the data typing of reviews as it is object now
data_copy['Reviews']=data_copy['Reviews'].astype('int')

# %%
data_copy['Reviews'].dtype
# Out:
# dtype('int32')

# %%
# Note always check what type of data each column has. Nominal, ordinal, Quaanitiative, categorical

# %%
data_copy.sample(10)
# Out:
#                                                App            Category  \
# 9087                     DYPhyzio-Physiology Forum              FAMILY
# 998                      LOL Pics (Funny Pictures)       ENTERTAINMENT
# 9733                          ER Surgery Simulator              FAMILY
# 1767                                Snake VS Block                GAME
# 8612                                     DN Snacks            BUSINESS
# 3678  XX HD Video downloader-Free Video Downloader       VIDEO_PLAYERS
# 9378                                   TAXI DRIVER              FAMILY
# 1063                                      Cash App             FINANCE
# 1775                              The Fish Master!                GAME
# 1427                   Pacifica - Stress & Anxiety  HEALTH_AND_FITNESS
#
#       Rating  Reviews                Size     Installs  Type Price  \
# 9087     NaN        4                1.3M         100+  Free     0
# ...

# %% [markdown]
# data_copy

# %%
def to_numeric(raw:str):
    if 'm' in raw.lower():
        return float(raw.replace('m','').replace('M',''))*(1024**2)
    if 'b' in raw.lower():
        return float(raw.replace('b','').replace('G',''))*(1024**3)
    elif 'k' in raw.lower():
        return float(raw.replace('k','').replace('K',''))*(1024)
        
        
data_copy['Size']=data_copy['Size'].apply(to_numeric)

# %%
import matplotlib.pyplot as plt
plt.hist(data_copy['Size'],bins=100)

# It is a power law distr. so Median is a better fillna
# Out:
# (array([323., 405., 567., 609., 471., 391., 336., 289., 297., 372., 198.,
#         196., 191., 194., 184., 149., 160., 133., 154., 139., 138., 114.,
#         117., 136., 143., 149.,  97.,  95., 103.,  84.,  70.,  63.,  79.,
#          63.,  72.,  60.,  76.,  55.,  56.,  62.,  48.,  41.,  47.,  61.,
#          40.,  59.,  37.,  59.,  45.,  44.,  33.,  35.,  43.,  29.,  30.,
#          31.,  37.,  26.,  38.,  36.,  26.,  32.,  41.,  15.,  10.,  16.,
#          32.,  18.,  23.,  27.,  14.,  19.,  15.,  20.,  13.,  27.,  13.,
#          23.,  11.,  13.,  11.,  21.,  15.,   9.,  17.,   8.,  13.,  14.,
#           9.,   6.,  22.,  15.,  16.,  17.,  18.,  26.,  20.,  16.,  39.,
#          16.]),
#  array([8.70400000e+03, 1.05719296e+06, 2.10568192e+06, 3.15417088e+06,
#         4.20265984e+06, 5.25114880e+06, 6.29963776e+06, 7.34812672e+06,
#         8.39661568e+06, 9.44510464e+06, 1.04935936e+07, 1.15420826e+07,
#         1.25905715e+07, 1.36390605e+07, 1.46875494e+07, 1.57360384e+07,
# ...

# %%
data_copy['Size']=data_copy['Size'].fillna(data_copy['Size'].median())

# %%
data_copy['Size']=data_copy['Size'].astype('int')

# %%
data_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size                int32
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data_copy['Price($)']=data_copy['Price($)'].str.replace('$','').astype('float')

# %%
data_copy.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    int32
# Size                       int32
# Installs(+)                int32
# Type                      object
# Price($)                 float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
data_copy = data_copy.rename(columns={'Price': 'Price($)'})

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Cleaning Install columns
data_copy['Installs']=data_copy['Installs'].str.replace(',','').str.replace('+','').astype('int')

# %%
data_copy=data_copy.rename(columns={'Installs':'Installs(+)'})

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
x=pd.to_datetime(data_copy['Last Updated'])
data_copy['Last Updated']=x

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data_copy=data_copy.drop_duplicates(keep='first')

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Automated EDA
# - autoviz
# -

# %% [markdown]
# # **EDA - Core**(Post Cleaning)

# %%
data_copy.shape
# Out:
# (10357, 13)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int32
#  4   Size            10357 non-null  int32
#  5   Installs(+)     10357 non-null  int32
#  6   Type            10356 non-null  object
#  7   Price($)        10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  datetime64[ns]
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(3), object(8)
# memory usage: 1011.4+ KB

# %%
data_copy.describe().T
# Out:
#                 count                           mean                  min  \
# Rating         8892.0                       4.187877                  1.0
# Reviews       10357.0                  405904.610602                  0.0
# Size          10357.0                21041088.674133               8704.0
# Installs(+)   10357.0                14157759.440668                  0.0
# Last Updated    10357  2017-11-14 09:25:19.320266496  2010-05-21 00:00:00
#
#                               25%                  50%                  75%  \
# Rating                        4.0                  4.3                  4.5
# Reviews                      32.0               1680.0              46416.0
# Size                    5976883.0           13631488.0           27262976.0
# Installs(+)                1000.0             100000.0            1000000.0
# Last Updated  2017-09-03 00:00:00  2018-05-20 00:00:00  2018-07-19 00:00:00
#
#                               max              std
# ...

# %%
data_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# - Univariate analysis- 1column needed
# - Bi-variate analysis- 2columns needed
# - Multi-variate analysis- >2columns needed

# %%
data_copy[data_copy.duplicated('App')]
# Out:
#                                             App       Category  Rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10647                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10715                        FarmersOnly Dating         DATING     3.0
# 10720        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10730                               FP Notebook        MEDICAL     4.5
# 10753            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews      Size  Installs(+)  Type Price($) Content Rating  \
# ...

# %%
data_copy=data_copy.drop_duplicates('App',keep='first')

# %%
data_copy[data_copy.duplicated('App')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs(+), Type, Price($), Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
numeric_features = [
    feature
    for feature in data_copy.columns
    if data_copy[feature].dtype != 'object'

]

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs(+)', 'Price($)', 'Last Updated']

# %%
data_copy.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    int32
# Size                       int32
# Installs(+)                int32
# Type                      object
# Price($)                  object
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
categorical_features = [
    feature
    for feature in data_copy.columns
    if data_copy[feature].dtype == 'object'

]
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
for col in categorical_features:
    print(data_copy[col].value_counts(normalize=True)*100)  # normalize will only turn the data in fraction in context to the whole data
    print('='*50)
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: proportion, Length: 9659, dtype: float64
# ...
# Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
import seaborn as sns
for col in categorical_features:
    sns.countplot(x=data_copy[col])
    plt.show()
    print('='*50)
# Out:
# C:\Users\Dvain\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128214 (\N{OPEN BOOK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Dvain\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28459 (\N{CJK UNIFIED IDEOGRAPH-6F2B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Dvain\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21654 (\N{CJK UNIFIED IDEOGRAPH-5496}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Dvain\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12304 (\N{LEFT BLACK LENTICULAR BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
for col in numeric_features:
    sns.kdeplot(data_copy[col])
    plt.show()

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Univariate analysis of numerical features",fontsize=20,fontweight='bold',y=1)
for i in range(0,numeric_features.__len__()):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=data_copy[numeric_features[i]],fill=True,color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# **Univariate Analysis Question**-
# 1. most popular category

# %%
data_copy['Category'].value_counts().plot(kind='pie',figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 2. Top 10 category

# %%
data_copy['Category'].value_counts()[:10].plot.barh(color='r')
# Out:
# <Axes: ylabel='Category'>

# %%
data_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews      Size  Installs(+)  Type  Price($) Content Rating  \
# 0      159  19922944        10000  Free       0.0       Everyone
# 1      967  14680064       500000  Free       0.0       Everyone
# 2    87510   9122611      5000000  Free       0.0       Everyone
# 3   215644  26214400     50000000  Free       0.0           Teen
# 4      967   2936012       100000  Free       0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
# Category with largest number of installation

df_cat_inst=data_copy.groupby(['Category'])['Installs(+)'].sum().sort_values(ascending=False).reset_index()
df_cat_inst.plot(kind='barh',x='Category',figsize=(10,8))
# Out:
# <Axes: ylabel='Category'>

# %% [markdown]
# 3. Top 5 most installed app in each category.

# %%
for Cat in data_copy['Category'].unique():
    print(data_copy[df['Category']==Cat].sort_values(by='Installs(+)',ascending=False)[:5])
# Out:
#                                                   App        Category  Rating  \
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 42                         Textgram - write on photos  ART_AND_DESIGN     4.4
# 45  Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN     4.7
# 19                                       ibis Paint X  ART_AND_DESIGN     4.6
# 12                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
#
#     Reviews      Size  Installs(+)  Type  Price($) Content Rating  \
# 3    215644  26214400     50000000  Free       0.0           Teen
# 42   295221  13631488     10000000  Free       0.0       Everyone
# 45   174531  25165824     10000000  Free       0.0       Everyone
# 19   224399  32505856     10000000  Free       0.0       Everyone
# 12    44829  20971520     10000000  Free       0.0           Teen
#
#           Genres Last Updated         Current Ver         Android Ver
# ...

# %%
# 3 How many apps are there in play store that get 5 star rating
data_copy[data_copy['Rating']==5.0].count()
# Out:
# App               271
# Category          271
# Rating            271
# Reviews           271
# Size              271
# Installs(+)       271
# Type              271
# Price($)          271
# Content Rating    271
# Genres            271
# Last Updated      271
# Current Ver       271
# Android Ver       271
# dtype: int64

# %%
# Which category apps users are reviewing the most
data_copy.groupby('Category').sum(numeric_only=True).sort_values('Reviews',ascending=0)
# Out:
#                      Rating    Reviews         Size  Installs(+)  Price($)
# Category
# GAME                 3873.6  622298709  39497253227  13878924415    284.31
# COMMUNICATION        1055.1  285811368   3864134813  11038276251     83.14
# TOOLS                2900.4  229356578   8040037804   8001771915    267.25
# SOCIAL                862.2  227927801   3849271043   5487867902     15.97
# FAMILY               6720.9  143825488  50650467907   4427941505   2399.86
# PHOTOGRAPHY          1093.4  105351270   4451062335   4649147655    118.28
# VIDEO_PLAYERS         598.6   67484568   2593822286   3926902720     10.46
# PRODUCTIVITY         1259.2   55590649   4897382544   5793091369    250.93
# PERSONALIZATION      1291.0   53543080   4471738079   1532494782    150.48
# SHOPPING              761.4   44551730   3192375880   1400348785      5.48
# SPORTS               1096.2   35348813   7734898034   1096474498    100.00
# ...

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=90)
sns.barplot(x='Category',y='Size',data=data_copy)
plt.show()

# %%
sns.pairplot(data=data_copy)

# %%
data_copy[:2]
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews      Size  Installs(+)  Type  Price($) Content Rating  \
# 0      159  19922944        10000  Free       0.0       Everyone
# 1      967  14680064       500000  Free       0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up

# %%
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
