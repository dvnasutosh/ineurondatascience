# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Steps to EDA
# 1. profiling and noting down
#    1. Univariate Analysis
#    2. Bi-variate Analysis
#    3. Multi-variate Analysis
# 2. Noting down each preprocessing

# %% [markdown]
# # Loading Dataset

# %%
travel_dataset=pd.read_csv('D:\study\ineuron\ineurondatascience\EDA\Practice\Dataset\data1\Travel.csv')
travel_dataset
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# # EDA ITER-1

# %% [markdown]
# ## Uni-variate Analysis

# %%
# CustomerID Univariate analysiS

travel_dataset['CustomerID']
# Out:
# 0       200000
# 1       200001
# 2       200002
# 3       200003
# 4       200004
#          ...
# 4883    204883
# 4884    204884
# 4885    204885
# 4886    204886
# 4887    204887
# Name: CustomerID, Length: 4888, dtype: int64

# %%
# Checking Duplication
travel_dataset[travel_dataset['CustomerID'].duplicated()]
# Verdict not duplicated
# TODO: Make customerId the index
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisiting, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisiting, Designation, MonthlyIncome]
# Index: []

# %%
# Univariate Analysis for ProdTaken

travel_dataset['ProdTaken'].value_counts().plot(kind='pie',labels=['No','Yes'],title='No of people who took the product',autopct=lambda p:f'{int((p/100)*travel_dataset.__len__())}')
# Out:
# <Axes: title={'center': 'No of people who took the product'}, ylabel='count'>

# %%
travel_dataset[travel_dataset['ProdTaken'].isna()]
# TODO Nothing much to do
# Out:
# Empty DataFrame
# Columns: [CustomerID, ProdTaken, Age, TypeofContact, CityTier, DurationOfPitch, Occupation, Gender, NumberOfPersonVisiting, NumberOfFollowups, ProductPitched, PreferredPropertyStar, MaritalStatus, NumberOfTrips, Passport, PitchSatisfactionScore, OwnCar, NumberOfChildrenVisiting, Designation, MonthlyIncome]
# Index: []

# %%
travel=travel_dataset

# %%
# univariate analysis `Age`
travel[travel['Age'].isna()]
# Out:
#       CustomerID  ProdTaken  Age    TypeofContact  CityTier  DurationOfPitch  \
# 4         200004          0  NaN     Self Enquiry         1              8.0
# 11        200011          0  NaN     Self Enquiry         1             21.0
# 19        200019          0  NaN     Self Enquiry         1              8.0
# 20        200020          0  NaN  Company Invited         1             17.0
# 21        200021          1  NaN     Self Enquiry         3             15.0
# ...          ...        ...  ...              ...       ...              ...
# 2410      202410          1  NaN     Self Enquiry         1             30.0
# 2413      202413          1  NaN     Self Enquiry         3             21.0
# 2427      202427          1  NaN     Self Enquiry         3             22.0
# 2430      202430          1  NaN     Self Enquiry         1             14.0
# 2435      202435          1  NaN     Self Enquiry         2             26.0
#
# ...
