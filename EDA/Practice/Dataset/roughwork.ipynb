# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
aug_test=pd.read_csv(r'D:\study\ineuron\ineurondatascience\EDA\Practice\Dataset\data0\aug_test.csv')
aug_test
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
aug_train = pd.read_csv(r'D:\study\ineuron\ineurondatascience\EDA\Practice\Dataset\data0\aug_train.csv')
aug_train
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
trn=aug_train.reset_index().drop('index',axis=1).set_index('enrollee_id')
trn.sort_index()
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 1            city_103                   0.920    Male
# 2            city_103                   0.920    Male
# 4            city_103                   0.920    Male
# 5             city_67                   0.855    Male
# 7            city_136                   0.897    Male
# ...               ...                     ...     ...
# 33375        city_103                   0.920    Male
# 33376         city_16                   0.910  Female
# 33377         city_65                   0.802    Male
# 33379        city_103                   0.920    Male
# 33380         city_83                   0.923    Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 1             No relevent experience       no_enrollment     High School
# 2             No relevent experience       no_enrollment             Phd
# ...

# %%
tst=aug_test.reset_index().drop('index',axis=1).set_index('enrollee_id')
tst.sort_index()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 3             city_99                   0.915    NaN   No relevent experience
# 28           city_103                   0.920   Male   No relevent experience
# 30           city_158                   0.766   Male  Has relevent experience
# 37           city_103                   0.920   Male   No relevent experience
# 40            city_21                   0.624   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 33300         city_50                   0.896   Male  Has relevent experience
# 33308         city_21                   0.624   Male  Has relevent experience
# 33316        city_103                   0.920   Male   No relevent experience
# 33343         city_21                   0.624   Male  Has relevent experience
# 33353        city_114                   0.926   Male  Has relevent experience
#
# ...

# %%
# combining both datasets
df= pd.concat([trn,tst])
df.sort_index().head(10)
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 1            city_103                   0.920    Male
# 2            city_103                   0.920    Male
# 3             city_99                   0.915     NaN
# 4            city_103                   0.920    Male
# 5             city_67                   0.855    Male
# 7            city_136                   0.897    Male
# 8            city_103                   0.920  Female
# 9             city_16                   0.910    Male
# 10           city_114                   0.926  Female
# 11           city_103                   0.920    Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 1             No relevent experience       no_enrollment     High School
# 2             No relevent experience       no_enrollment             Phd
# 3             No relevent experience    Full time course     High School
# ...

# %% [markdown]
# # **EDA 1** - *Figuring the data out*

# %%
# finding missing enrolleee numbers

missing_enrollee = [
    i for i in range(max(df.index)) if i not in df.index
]
str(missing_enrollee)
# Out:
# '[0, 6, 12, 14, 15, 16, 22, 23, 24, 26, 27, 29, 31, 34, 38, 42, 43, 51, 56, 57, 59, 60, 61, 63, 66, 68, 76, 78, 82, 88, 90, 91, 92, 93, 94, 95, 96, 97, 100, 104, 108, 112, 120, 123, 127, 128, 131, 136, 144, 145, 147, 149, 150, 151, 152, 153, 159, 160, 161, 165, 166, 168, 171, 175, 176, 183, 184, 187, 192, 193, 194, 196, 197, 199, 203, 205, 206, 207, 209, 210, 212, 216, 222, 224, 226, 228, 230, 232, 233, 237, 242, 243, 244, 247, 249, 253, 254, 255, 256, 259, 260, 261, 263, 266, 267, 271, 274, 275, 279, 282, 283, 286, 290, 291, 292, 296, 298, 303, 304, 305, 310, 314, 318, 323, 326, 329, 330, 331, 333, 335, 340, 341, 342, 350, 353, 354, 355, 357, 358, 360, 362, 367, 368, 369, 371, 376, 377, 379, 383, 387, 392, 393, 395, 398, 404, 406, 408, 409, 415, 416, 424, 426, 427, 429, 432, 434, 435, 439, 449, 454, 456, 457, 466, 467, 469, 470, 472, 474, 475, 476, 477, 478, 479, 483, 486, 487, 492, 498, 499, 504, 507, 508, 510, 513, 520, 521, 522, 523, 524, 525, 526, 529, 530, 532, 533, 536, 537, 5
# ...

# %%
df.city.value_counts()
# TODO: change `city` feature into numbers
# Out:
# city
# city_103    4828
# city_21     3020
# city_16     1701
# city_114    1491
# city_160     958
#             ...
# city_8         4
# city_111       3
# city_129       3
# city_171       2
# city_140       1
# Name: count, Length: 123, dtype: int64

# %%
df[df.duplicated(keep=False)]
# Duplication is probably none
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 9645          city_16                   0.910    Male
# 6685          city_16                   0.910    Male
# 22319         city_21                   0.624    Male
# 20376        city_160                   0.920    Male
# 5911         city_103                   0.920    Male
# ...               ...                     ...     ...
# 26349        city_103                   0.920    Male
# 26961        city_103                   0.920  Female
# 33047        city_103                   0.920    Male
# 13142        city_103                   0.920    Male
# 3862         city_103                   0.920    Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 9645         Has relevent experience       no_enrollment        Graduate
# 6685         Has relevent experience       no_enrollment        Graduate
# ...

# %%
df['city'].unique()
# Out:
# array(['city_103', 'city_40', 'city_21', 'city_115', 'city_162',
#        'city_176', 'city_160', 'city_46', 'city_61', 'city_114',
#        'city_13', 'city_159', 'city_102', 'city_67', 'city_100',
#        'city_16', 'city_71', 'city_104', 'city_64', 'city_101', 'city_83',
#        'city_105', 'city_73', 'city_75', 'city_41', 'city_11', 'city_93',
#        'city_90', 'city_36', 'city_20', 'city_57', 'city_152', 'city_19',
#        'city_65', 'city_74', 'city_173', 'city_136', 'city_98', 'city_97',
#        'city_50', 'city_138', 'city_82', 'city_157', 'city_89',
#        'city_150', 'city_70', 'city_175', 'city_94', 'city_28', 'city_59',
#        'city_165', 'city_145', 'city_142', 'city_26', 'city_12',
#        'city_37', 'city_43', 'city_116', 'city_23', 'city_99', 'city_149',
#        'city_10', 'city_45', 'city_80', 'city_128', 'city_158',
#        'city_123', 'city_7', 'city_72', 'city_106', 'city_143', 'city_78',
# ...

# %%
city_code=[]
for i in df['city'].unique():
    s = ''.join(j for j in i if str.isnumeric(j))
    city_code.append(int(s))
city_code.sort()
city_code
# Out:
# [1,
#  2,
#  7,
#  8,
#  9,
#  10,
#  11,
#  12,
#  13,
#  14,
#  16,
#  18,
#  19,
#  20,
#  21,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  31,
#  33,
#  36,
#  37,
#  39,
#  40,
#  41,
#  42,
#  43,
#  44,
#  45,
#  46,
#  48,
#  50,
#  53,
#  54,
#  55,
#  57,
#  59,
#  61,
#  62,
#  64,
#  65,
#  67,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  89,
#  90,
#  91,
#  93,
#  94,
#  97,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  109,
#  111,
#  114,
#  115,
#  116,
#  117,
#  118,
#  120,
#  121,
#  123,
#  126,
#  127,
#  128,
#  129,
#  131,
#  133,
#  134,
#  136,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  149,
#  150,
#  152,
#  155,
#  157,
#  158,
#  159,
#  160,
#  162,
#  165,
#  166,
#  167,
#  171,
#  173,
#  175,
#  176,
#  179,
#  180]

# %%
df.head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %%
df['relevent_experience'].value_counts().plot(kind='pie',autopct=lambda p:f'{int((p/100)*df.__len__())}')
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %%
df['major_discipline'].value_counts().plot(
                                            kind='pie',
                                            autopct=lambda p: f'{int((p/100)*df.__len__())}',
                                            figsize=(10,15)
                                        )
# Out:
# <Axes: ylabel='count'>

# %%
df['city_development_index'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Out:
# array(['1', '>4', 'never', '4', '3', '2', nan], dtype=object)
