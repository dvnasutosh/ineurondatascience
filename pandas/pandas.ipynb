# %%
# pandas library is a data analytics tool.
import pandas as pd
pd
# Out:
# <module 'pandas' from 'c:\\Python310\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_excel(r'D:\study\0ineurondatascience\pandas\data fsds\Attribute DataSet.xlsx')
# pd.read_excel is used to read excell file
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# all tabular data read or stored using pandas are stored in a custom datatype known as dataframe.
# This dataframe is just a tabular data or a multi dimensional array with some added data analytics specific functionalities.
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# If you have to read data from another sheet in the excell file
df = pd.read_excel(r'D:\study\0ineurondatascience\pandas\data fsds\Attribute DataSet.xlsx',header=None)
# Header parameter takes the row index which the program intends to treat as a header. Default: column 0. It takes None to have NO GIVEN ROW as header but use indexes as column name
# Out:
#              0        1        2       3     4       5          6   \
# 0      Dress_ID    Style    Price  Rating  Size  Season   NeckLine
# 1    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 2    1212192089   Casual      Low       0     L  Summer     o-neck
# 3    1190380701  vintage     High       0     L  Automn     o-neck
# 4     966005983    Brief  Average     4.6     L  Spring     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 496   713391965   Casual      Low     4.7     M  Spring     o-neck
# 497   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 498   532874347   Casual  Average     4.7     M  Summer     v-neck
# 499   655464934   Casual  Average     4.6     L  winter  boat-neck
# 500   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#                7          8           9           10          11  \
# 0    SleeveLength  waiseline    Material  FabricType  Decoration
# ...

# %%
df = pd.read_excel(r'D:\study\0ineurondatascience\pandas\data fsds\Attribute DataSet.xlsx',names=['A','B','C','D','E'])
df
# names parameters takes custom names for each column
# column names are allocaed to the right most columns first.
# Out:
#                                                                                     A  \
# 1006032852 Sexy    Low     4.6 M    Summer o-neck    sleevless empire             NaN
# 1212192089 Casual  Low     0.0 L    Summer o-neck    Petal     natural     microfiber
# 1190380701 vintage High    0.0 L    Automn o-neck    full      natural       polyster
# 966005983  Brief   Average 4.6 L    Spring o-neck    full      natural           silk
# 876339541  cute    Low     4.5 M    Summer o-neck    butterfly natural  chiffonfabric
# ...                                                                               ...
# 713391965  Casual  Low     4.7 M    Spring o-neck    full      natural       polyster
# 722565148  Sexy    Low     4.3 free Summer o-neck    full      empire          cotton
# 532874347  Casual  Average 4.7 M    Summer v-neck    full      empire          cotton
# 655464934  Casual  Average 4.6 L    winter boat-neck sleevless empire            silk
# ...

# %%
df.tail(10) 
# Shows last 10 rows
# Out:
#                                                                                 A  \
# 641665398 Casual   Low     4.8 free winter bowneck   full       natural  polyster
# 964917582 Casual   Average 5.0 L    Summer o-neck    sleevless  natural    cotton
# 859922576 cute     Average 4.6 M    Spring o-neck    halfsleeve natural   acrylic
# 817353671 bohemian Low     4.6 free Summer o-neck    sleevless  natural    cotton
# 990559192 Brief    Average 4.7 M    winter o-neck    halfsleeve natural   acrylic
# 713391965 Casual   Low     4.7 M    Spring o-neck    full       natural  polyster
# 722565148 Sexy     Low     4.3 free Summer o-neck    full       empire     cotton
# 532874347 Casual   Average 4.7 M    Summer v-neck    full       empire     cotton
# 655464934 Casual   Average 4.6 L    winter boat-neck sleevless  empire       silk
# 919930954 Casual   Low     4.4 free Summer v-neck    short      empire     cotton
#
# ...

# %%
df.head(10)
# Show first 10 records
# Out:
#                                                                                   A  \
# 1006032852 Sexy     Low     4.6 M    Summer o-neck sleevless empire             NaN
# 1212192089 Casual   Low     0.0 L    Summer o-neck Petal     natural     microfiber
# 1190380701 vintage  High    0.0 L    Automn o-neck full      natural       polyster
# 966005983  Brief    Average 4.6 L    Spring o-neck full      natural           silk
# 876339541  cute     Low     4.5 M    Summer o-neck butterfly natural  chiffonfabric
# 1068332458 bohemian Low     0.0 M    Summer v-neck sleevless empire             NaN
# 1220707172 Casual   Average 0.0 XL   Summer o-neck full      NaN             cotton
# 1219677488 Novelty  Average 0.0 free Automn o-neck short     natural       polyster
# 1113094204 Flare    Average 0.0 free Spring v-neck short     empire          cotton
# 985292672  bohemian Low     0.0 free Summer v-neck sleevless natural          nylon
#
# ...

# %%
csv = pd.read_csv(r'D:\study\0ineurondatascience\pandas\data fsds\haberman.csv',names=['Age','Year of Operation','Positive Count','SURVIVAL STATUS'],sep=',')
csv
# sep parameter is used to add any delimeter we wish to form csv using
# Out:
#      Age  Year of Operation  Positive Count  SURVIVAL STATUS
# 0     30                 64               1                1
# 1     30                 62               3                1
# 2     30                 65               0                1
# 3     31                 59               2                1
# 4     31                 65               4                1
# ..   ...                ...             ...              ...
# 301   75                 62               1                1
# 302   76                 67               0                1
# 303   77                 65               3                1
# 304   78                 65               1                2
# 305   83                 58               2                2
#
# [306 rows x 4 columns]

# %%
# read data from uri
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
html=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
type(html)
print(html)
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
json_file=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# print(type(json_file['user']))
pd.DataFrame.from_dict(json_file.user[1],orient='index')
# json_file.user[1]
# pd.DataFrame.from_dict(``)
# Out:
#                                                                      0
# login                                                       lukemanley
# id                                                             8519523
# node_id                                           MDQ6VXNlcjg1MTk1MjM=
# avatar_url           https://avatars.githubusercontent.com/u/851952...
# gravatar_id
# url                            https://api.github.com/users/lukemanley
# html_url                                 https://github.com/lukemanley
# followers_url        https://api.github.com/users/lukemanley/followers
# following_url        https://api.github.com/users/lukemanley/follow...
# gists_url            https://api.github.com/users/lukemanley/gists{...
# starred_url          https://api.github.com/users/lukemanley/starre...
# subscriptions_url    https://api.github.com/users/lukemanley/subscr...
# organizations_url         https://api.github.com/users/lukemanley/orgs
# ...

# %%
json_file=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
df=pd.DataFrame.from_records(json_file)
df.to_csv('into.csv',sep='$',index=None)
# pd.read_sql()

# %%
from cmath import nan


type(nan)
# Out:
# float
